# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khanyo-byte/FLYRNKINT/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
print("I chose the Refresh / Content Opportunity Scoring lane because it focuses on helping content teams decide which pages should be reviewed first. Rather than updating every page, this project aims to prioritise pages using observable search and engagement signals so that limited time is spent where it is likely to have the greatest impact.")

# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# I chose the Refresh / Content Opportunity Scoring lane because it focuses on helping content teams decide which pages should be reviewed first. Rather than updating every page, this project aims to prioritise pages using observable search and engagement signals so that limited time is spent where it is likely to have the greatest impact.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
print("Decision: Which pages should be reviewed first.")
print("Who acts on it: A content manager or SEO specialist -someone who needs to review the highest-priority pages before updating content. ")
print("Cost: Important pages continue losing traffic because they weren't reviewed  ")
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Decision: Which pages should be reviewed first.
# Who acts on it: A content manager or SEO specialist -someone who needs to review the highest-priority pages before updating content.
# Cost: Important pages continue losing traffic because they weren't reviewed

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
import pandas as pd

# Load the dataset
df = pd.read_csv("content_refresh_anonymized.csv")

# Show the size of the dataset
print("Dataset shape:", df.shape)

# Show how many pages are in each trend category
print("\nTrend direction counts:")
print(df["trend_direction"].value_counts())

# Show summary statistics for impressions
print("\nImpressions (90 days):")
print(df["impressions_90d"].describe())
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Dataset shape: (30000, 44)
#
# Trend direction counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Impressions (90 days):
# count     30000.000000
# mean       5200.366300
# std       16838.019547
# min           1.000000
# 25%          81.000000
# 50%         731.000000
# 75%        3615.250000
# max      517715.000000
# Name: impressions_90d, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
print("This project aims to identify patterns in observable search and engagement data that can help prioritise content pages for review")
print("The recommendations produced are intended to support decision-making by helping content managers identify which pages may deserve attention first.")
print("This project cannot prove that refreshing a page will cause its performance to improve, nor can it predict Google's ranking decisions.")
print("Any findings will describe observed relationships in the available data and should be used as decision-support rather than guarantees of future outcomes.")
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# This project aims to identify patterns in observable search and engagement data that can help prioritise content pages for review
# The recommendations produced are intended to support decision-making by helping content managers identify which pages may deserve attention first.
# This project cannot prove that refreshing a page will cause its performance to improve, nor can it predict Google's ranking decisions.
# Any findings will describe observed relationships in the available data and should be used as decision-support rather than guarantees of future outcomes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
